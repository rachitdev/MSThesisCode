# %% [markdown]
# ### Creating Multiple DataSets according to the year

# %%
import pandas as pd

# %%
df2006 = pd.read_excel('fsi-2006.xlsx', engine='openpyxl')
df2007 = pd.read_excel('fsi-2007.xlsx', engine='openpyxl')
df2008 = pd.read_excel('fsi-2008.xlsx', engine='openpyxl')
df2009 = pd.read_excel('fsi-2009.xlsx', engine='openpyxl')
df2010 = pd.read_excel('fsi-2010.xlsx', engine='openpyxl')
df2011 = pd.read_excel('fsi-2011.xlsx', engine='openpyxl')
df2012 = pd.read_excel('fsi-2012.xlsx', engine='openpyxl')
df2013 = pd.read_excel('fsi-2013.xlsx', engine='openpyxl')
df2014 = pd.read_excel('fsi-2014.xlsx', engine='openpyxl')
df2015 = pd.read_excel('fsi-2015.xlsx', engine='openpyxl')
df2016 = pd.read_excel('fsi-2016.xlsx', engine='openpyxl')
df2017 = pd.read_excel('fsi-2017.xlsx', engine='openpyxl')
df2018 = pd.read_excel('fsi-2018.xlsx', engine='openpyxl')
df2019 = pd.read_excel('fsi-2019.xlsx', engine='openpyxl')
df2020 = pd.read_excel('fsi-2020.xlsx', engine='openpyxl')

# %%
del df2019['Change from Previous Year']
del df2019['Unnamed: 17']
del df2019['Unnamed: 18']
del df2020['Change from Previous Year']
del df2020['Unnamed: 17']
del df2020['Unnamed: 18']
del df2020['Unnamed: 19']
del df2020['Unnamed: 20']
del df2020['Unnamed: 21']
del df2020['Unnamed: 22']
del df2020['Unnamed: 23']
del df2020['Unnamed: 24']
del df2020['Unnamed: 25']
del df2020['Unnamed: 26']
del df2020['Unnamed: 27']
del df2020['Unnamed: 28']
del df2020['Unnamed: 29']
del df2020['Unnamed: 30']
del df2020['Unnamed: 31']
del df2020['Unnamed: 32']
del df2020['Unnamed: 33']
del df2020['Unnamed: 34']
del df2020['Unnamed: 35']
del df2020['Unnamed: 36']
del df2020['Unnamed: 37']
del df2020['Unnamed: 38']

# %%
df2006.dropna(inplace = True)
df2007.dropna(inplace = True)
df2008.dropna(inplace = True)
df2009.dropna(inplace = True)
df2010.dropna(inplace = True)
df2011.dropna(inplace = True)
df2012.dropna(inplace = True)
df2013.dropna(inplace = True)
df2014.dropna(inplace = True)
df2015.dropna(inplace = True)
df2016.dropna(inplace = True)
df2017.dropna(inplace = True)
df2018.dropna(inplace = True)
df2019.dropna(inplace = True)
df2020.dropna(inplace = True)

# %%
df2006.tail()
# Out:
#           Country       Year   Rank  Total  C1: Security Apparatus  \
# 141  Switzerland  2006-01-01  142nd   18.7                     1.0
# 142      Ireland  2006-01-01  143rd   18.6                     1.0
# 143      Finland  2006-01-01  144th   18.2                     1.0
# 144       Sweden  2006-01-01  144th   18.2                     1.0
# 145       Norway  2006-01-01  146th   16.8                     1.0
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 141                       1.0                  2.0          1.2
# 142                       1.0                  1.0          1.9
# 143                       1.0                  1.0          2.2
# 144                       1.0                  1.0          1.2
# 145                       1.0                  1.0          1.8
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 141                      2.5                               2.0
# ...

# %%
df2007.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 172  Switzerland 2007-01-01  172nd   20.2                     1.0
# 173      Ireland 2007-01-01  173rd   19.5                     1.0
# 174       Sweden 2007-01-01  174th   19.3                     0.9
# 175      Finland 2007-01-01  175th   18.5                     0.9
# 176       Norway 2007-01-01  176th   17.1                     1.0
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 172                       1.0                  2.1          1.5
# 173                       1.0                  1.0          2.1
# 174                       1.0                  1.0          1.3
# 175                       0.7                  1.0          2.2
# 176                       1.0                  1.0          2.1
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 172                      2.6                               2.0
# ...

# %%
df2008.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 172  Switzerland 2008-01-01  173rd   20.3                     1.0
# 173      Ireland 2008-01-01  174th   19.9                     1.0
# 174       Sweden 2008-01-01  175th   19.8                     0.9
# 175      Finland 2008-01-01  176th   18.4                     0.9
# 176       Norway 2008-01-01  177th   16.8                     1.0
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 172                       1.0                  2.6          1.5
# 173                       1.0                  1.0          2.0
# 174                       1.0                  1.3          1.2
# 175                       0.7                  1.0          2.0
# 176                       1.0                  1.0          1.8
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 172                      2.6                               2.0
# ...

# %%
df2009.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 172      Ireland 2009-01-01  173rd   21.6                     1.1
# 173  Switzerland 2009-01-01  174th   21.2                     1.0
# 174       Sweden 2009-01-01  175th   20.6                     1.1
# 175      Finland 2009-01-01  176th   19.2                     0.9
# 176       Norway 2009-01-01  177th   18.3                     1.1
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 172                       1.3                  1.0          2.7
# 173                       1.0                  2.9          2.1
# 174                       1.3                  1.3          1.6
# 175                       0.9                  1.2          2.4
# 176                       1.1                  1.3          2.3
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 172                      3.0                               2.0
# ...

# %%
df2010.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 172      Ireland 2010-01-01  173rd   22.4                     1.4
# 173  Switzerland 2010-01-01  174th   21.8                     1.2
# 174       Sweden 2010-01-01  175th   20.9                     1.3
# 175      Finland 2010-01-01  176th   19.3                     1.0
# 176       Norway 2010-01-01  177th   18.7                     1.2
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 172                       1.5                  1.0          3.3
# 173                       1.0                  3.3          2.4
# 174                       1.3                  1.3          2.2
# 175                       1.0                  1.2          3.0
# 176                       1.1                  1.3          2.6
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 172                      2.8                               2.0
# ...

# %%
df2011.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 172      Denmark 2011-01-01  173rd   23.8                     1.5
# 173  Switzerland 2011-01-01  174th   23.2                     1.4
# 174       Sweden 2011-01-01  175th   22.8                     2.3
# 175       Norway 2011-01-01  176th   20.4                     1.2
# 176      Finland 2011-01-01  177th   19.7                     1.0
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 172                       1.0                  3.3          2.5
# 173                       1.0                  3.5          2.4
# 174                       1.8                  1.3          1.9
# 175                       1.2                  1.3          2.9
# 176                       1.2                  1.7          2.8
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 172                      1.7                               2.1
# ...

# %%
df2012.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 173       Norway 2012-01-01  173rd   23.9                     3.0
# 174  Switzerland 2012-01-01  174th   23.3                     1.7
# 175      Denmark 2012-01-01  175th   23.0                     1.8
# 176       Sweden 2012-01-01  176th   21.3                     2.5
# 177      Finland 2012-01-01  177th   20.0                     1.3
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.2                  3.6          2.4
# 174                       1.0                  3.2          2.2
# 175                       1.0                  3.0          2.2
# 176                       1.8                  1.0          1.6
# 177                       1.2                  1.4          2.9
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      1.8                               1.5
# ...

# %%
df2013.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 173      Denmark 2013-01-01  174th   21.9                     1.5
# 174       Norway 2013-01-01  175th   21.5                     2.7
# 175  Switzerland 2013-01-01  175th   21.5                     1.4
# 176       Sweden 2013-01-01  177th   19.7                     2.2
# 177      Finland 2013-01-01  178th   18.0                     1.0
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.4                  3.4          1.9
# 174                       1.1                  3.6          1.9
# 175                       1.0                  3.5          2.3
# 176                       1.8                  1.0          1.7
# 177                       1.1                  1.4          3.2
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      1.6                               1.9
# ...

# %%
df2014.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 173  Switzerland 2014-01-01  174th   23.3                     1.7
# 174       Norway 2014-01-01  175th   23.0                     2.8
# 175      Denmark 2014-01-01  176th   22.8                     1.8
# 176       Sweden 2014-01-01  177th   21.4                     2.4
# 177      Finland 2014-01-01  178th   18.7                     1.3
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.0                  3.5          2.2
# 174                       1.1                  3.7          2.0
# 175                       1.4                  3.4          2.2
# 176                       1.8                  1.0          2.0
# 177                       1.1                  1.3          3.5
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      2.4                               2.4
# ...

# %%
df2015.tail()
# Out:
#         Country       Year   Rank  Total  C1: Security Apparatus  \
# 173  Luxembourg 2015-01-01  174th   22.1                     2.0
# 174     Denmark 2015-01-01  175th   21.4                     1.5
# 175      Norway 2015-01-01  176th   20.9                     2.5
# 176      Sweden 2015-01-01  177th   20.2                     2.1
# 177     Finland 2015-01-01  178th   17.7                     1.4
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       3.4                  3.1          1.5
# 174                       1.4                  3.6          2.5
# 175                       1.1                  3.7          1.7
# 176                       1.8                  1.3          2.3
# 177                       1.1                  1.6          3.8
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      1.5                               2.1
# ...

# %%
df2016.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 173  Switzerland 2016-01-01  174th   21.8                     1.3
# 174      Denmark 2016-01-01  175th   21.5                     1.4
# 175  New Zealand 2016-01-01  176th   21.3                     1.4
# 176       Norway 2016-01-01  177th   21.2                     2.2
# 177      Finland 2016-01-01  178th   18.8                     1.4
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.0                  3.8          2.5
# 174                       1.4                  4.6          2.2
# 175                       1.1                  3.8          3.8
# 176                       1.1                  3.8          1.7
# 177                       1.1                  2.0          3.7
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      2.4                               1.8
# ...

# %%
df2017.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 173       Sweden 2017-01-01  174th   22.1                     2.1
# 174      Denmark 2017-01-01  175th   21.5                     1.7
# 175  Switzerland 2017-01-01  176th   21.1                     1.1
# 176       Norway 2017-01-01  177th   20.5                     2.0
# 177      Finland 2017-01-01  178th   18.7                     1.7
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.8                  1.5          1.8
# 174                       1.4                  4.4          2.0
# 175                       1.0                  3.6          2.3
# 176                       1.1                  3.6          2.2
# 177                       1.1                  1.8          3.5
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      1.8                               1.5
# ...

# %%
df2018.tail()
# Out:
#          Country       Year   Rank      Total  C1: Security Apparatus  \
# 173      Iceland 2018-01-01  174th  20.300000                     0.8
# 174      Denmark 2018-01-01  175th  19.785177                     1.4
# 175  Switzerland 2018-01-01  176th  19.209526                     1.4
# 176       Norway 2018-01-01  177th  18.258722                     1.8
# 177      Finland 2018-01-01  178th  17.934252                     2.2
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.8                  1.1      3.20000
# 174                       1.4                  4.4      1.73386
# 175                       1.0                  3.6      2.00000
# 176                       1.1                  3.4      2.00000
# 177                       1.4                  1.5      3.20000
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      0.9                          2.600000
# ...

# %%
df2019.tail()
# Out:
#          Country       Year   Rank  Total  C1: Security Apparatus  \
# 173    Australia 2019-01-01  174th   19.7                     2.7
# 174      Denmark 2019-01-01  175th   19.5                     1.3
# 175  Switzerland 2019-01-01  176th   18.7                     1.1
# 176       Norway 2019-01-01  177th   18.0                     2.1
# 177      Finland 2019-01-01  178th   16.9                     2.5
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.7                  3.3          1.6
# 174                       1.4                  4.3          1.6
# 175                       1.0                  3.3          1.9
# 176                       1.1                  3.3          1.9
# 177                       1.4                  1.2          2.9
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      1.6                               1.0
# ...

# %%
df2020.tail()
# Out:
#          Country       Year   Rank      Total  C1: Security Apparatus  \
# 173      Iceland 2020-01-01  174th  17.800000                     1.0
# 174      Denmark 2020-01-01  175th  17.213587                     1.6
# 175  Switzerland 2020-01-01  176th  17.094086                     1.4
# 176       Norway 2020-01-01  177th  16.191210                     1.8
# 177      Finland 2020-01-01  178th  14.626666                     2.8
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.8                  0.7      2.80000
# 174                       1.4                  4.0      1.30000
# 175                       1.0                  3.0      1.60000
# 176                       1.1                  3.6      1.69121
# 177                       1.4                  0.9      2.60000
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173                      1.0                               2.2
# ...

# %%
dataframes = [df2006, df2007, df2008, df2009, df2010, df2011, df2012, df2013, df2014, df2015, df2016, 
             df2017, df2018, df2019, df2020]

# %%
fsi6_20_df = pd.concat(dataframes)

# %%
fsi6_20_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2633 entries, 0 to 177
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           2633 non-null   object
#  1   Year                              2633 non-null   datetime64[ns]
#  2   Rank                              2633 non-null   object
#  3   Total                             2633 non-null   float64
#  4   C1: Security Apparatus            2633 non-null   float64
#  5   C2: Factionalized Elites          2633 non-null   float64
#  6   C3: Group Grievance               2633 non-null   float64
#  7   E1: Economy                       2633 non-null   float64
#  8   E2: Economic Inequality           2633 non-null   float64
#  9   E3: Human Flight and Brain Drain  2633 non-null   float64
#  10  P1: State Legitimacy              2633 non-null   float64
# ...

# %%
# Deleting  the coloumn which has NaN values.
# del fsi6_20_df['Change from Previous Year']
# del fsi6_20_df['Rank']
# del fsi6_20_df['Total']
# del fsi6_20_df['Unnamed: 17']
# del fsi6_20_df['Unnamed: 18']
# del fsi6_20_df['Unnamed: 19']
# del fsi6_20_df['Unnamed: 20']
# del fsi6_20_df['Unnamed: 21']
# del fsi6_20_df['Unnamed: 22']
# del fsi6_20_df['Unnamed: 23']
# del fsi6_20_df['Unnamed: 24']
# del fsi6_20_df['Unnamed: 25']
# del fsi6_20_df['Unnamed: 26']
# del fsi6_20_df['Unnamed: 27']
# del fsi6_20_df['Unnamed: 28']
# del fsi6_20_df['Unnamed: 29']
# del fsi6_20_df['Unnamed: 30']
# del fsi6_20_df['Unnamed: 31']
# del fsi6_20_df['Unnamed: 32']
# del fsi6_20_df['Unnamed: 33']
# del fsi6_20_df['Unnamed: 34']
# del fsi6_20_df['Unnamed: 35']
# del fsi6_20_df['Unnamed: 36']
# del fsi6_20_df['Unnamed: 37']
# del fsi6_20_df['Unnamed: 38']

# %%
fsi6_20_df[fsi6_20_df.Country.eq('India')]
# Out:
#     Country       Year   Rank      Total  C1: Security Apparatus  \
# 92    India 2006-01-01   93rd  70.400000                4.500000
# 109   India 2007-01-01  109th  70.800000                5.000000
# 97    India 2008-01-01   98th  72.900000                6.600000
# 86    India 2009-01-01   87th  77.800000                7.100000
# 78    India 2010-01-01   79th  79.200000                7.600000
# 75    India 2011-01-01   76th  79.300000                7.800000
# 78    India 2012-01-01   78th  78.000000                7.500000
# 78    India 2013-01-01   79th  77.500000                7.800000
# 80    India 2014-01-01   81st  76.900000                7.900000
# 68    India 2015-01-01   69th  79.300000                7.900000
# 69    India 2016-01-01   70th  79.600000                7.600000
# 71    India 2017-01-01   72nd  77.900000                7.400000
# 71    India 2018-01-01   72nd  76.308510                7.100000
# ...

# %%
# Basic Data cleaning checks
fsi6_20_df.isna().sum()
# Out:
# Country                             0
# Year                                0
# Rank                                0
# Total                               0
# C1: Security Apparatus              0
# C2: Factionalized Elites            0
# C3: Group Grievance                 0
# E1: Economy                         0
# E2: Economic Inequality             0
# E3: Human Flight and Brain Drain    0
# P1: State Legitimacy                0
# P2: Public Services                 0
# P3: Human Rights                    0
# S1: Demographic Pressures           0
# S2: Refugees and IDPs               0
# X1: External Intervention           0
# dtype: int64

# %%
fsi6_20_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2633 entries, 0 to 177
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           2633 non-null   object
#  1   Year                              2633 non-null   datetime64[ns]
#  2   Rank                              2633 non-null   object
#  3   Total                             2633 non-null   float64
#  4   C1: Security Apparatus            2633 non-null   float64
#  5   C2: Factionalized Elites          2633 non-null   float64
#  6   C3: Group Grievance               2633 non-null   float64
#  7   E1: Economy                       2633 non-null   float64
#  8   E2: Economic Inequality           2633 non-null   float64
#  9   E3: Human Flight and Brain Drain  2633 non-null   float64
#  10  P1: State Legitimacy              2633 non-null   float64
# ...

# %%
# For Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize = (20,10))        
sns.heatmap(fsi6_20_df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
# Preparing Data for making country cluster
fsi6_20_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2633 entries, 0 to 177
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           2633 non-null   object
#  1   Year                              2633 non-null   datetime64[ns]
#  2   Rank                              2633 non-null   object
#  3   Total                             2633 non-null   float64
#  4   C1: Security Apparatus            2633 non-null   float64
#  5   C2: Factionalized Elites          2633 non-null   float64
#  6   C3: Group Grievance               2633 non-null   float64
#  7   E1: Economy                       2633 non-null   float64
#  8   E2: Economic Inequality           2633 non-null   float64
#  9   E3: Human Flight and Brain Drain  2633 non-null   float64
#  10  P1: State Legitimacy              2633 non-null   float64
# ...

# %%
df_cluster = fsi6_20_df.copy()

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2633 entries, 0 to 177
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           2633 non-null   object
#  1   Year                              2633 non-null   datetime64[ns]
#  2   Rank                              2633 non-null   object
#  3   Total                             2633 non-null   float64
#  4   C1: Security Apparatus            2633 non-null   float64
#  5   C2: Factionalized Elites          2633 non-null   float64
#  6   C3: Group Grievance               2633 non-null   float64
#  7   E1: Economy                       2633 non-null   float64
#  8   E2: Economic Inequality           2633 non-null   float64
#  9   E3: Human Flight and Brain Drain  2633 non-null   float64
#  10  P1: State Legitimacy              2633 non-null   float64
# ...

# %%
df_cluster.shape
# Out:
# (2633, 16)

# %%
# Lowering the country names for normalizing them
df_cluster['Country'] = df_cluster['Country'].str.lower()

# %%
df_cluster['Year'] = df_cluster['Year'].apply(str)

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2633 entries, 0 to 177
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           2633 non-null   object
#  1   Year                              2633 non-null   object
#  2   Rank                              2633 non-null   object
#  3   Total                             2633 non-null   float64
#  4   C1: Security Apparatus            2633 non-null   float64
#  5   C2: Factionalized Elites          2633 non-null   float64
#  6   C3: Group Grievance               2633 non-null   float64
#  7   E1: Economy                       2633 non-null   float64
#  8   E2: Economic Inequality           2633 non-null   float64
#  9   E3: Human Flight and Brain Drain  2633 non-null   float64
#  10  P1: State Legitimacy              2633 non-null   float64
# ...

# %%
df_cluster.shape
# Out:
# (2633, 16)

# %%
# Now we are going to join the Country and year column to make a unique country name 
# to do our further analysis
# df_cluster = df_cluster[:2633]

# %%
df_cluster['Country_Year']= df_cluster['Country'].str.cat(df_cluster['Year'], sep ="_")

# %%
df_cluster.head()
# Out:
#                      Country                 Year Rank  Total  \
# 0                      sudan  2006-01-01 00:00:00  1st  112.3
# 1  congo democratic republic  2006-01-01 00:00:00  2nd  110.1
# 2              cote d'ivoire  2006-01-01 00:00:00  3rd  109.2
# 3                       iraq  2006-01-01 00:00:00  4th  109.0
# 4                   zimbabwe  2006-01-01 00:00:00  5th  108.9
#
#    C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                     9.8                       9.1                  9.7
# 1                     9.8                       9.6                  9.1
# 2                     9.8                       9.8                  9.8
# 3                     9.8                       9.7                  9.8
# 4                     9.4                       8.5                  8.5
#
#    E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0          7.5                      9.2                               9.1
# ...

# %%
# Now we are going to join the Country and year column to make a unique country name to do our further analysis
# df_cluster['Country_Year'] = df_cluster[['Country', 'Year']].apply(lambda x: '_'.join(x), axis = 1)

# %%
df_cluster.tail()
# Out:
#          Country                 Year   Rank      Total  \
# 173      iceland  2020-01-01 00:00:00  174th  17.800000
# 174      denmark  2020-01-01 00:00:00  175th  17.213587
# 175  switzerland  2020-01-01 00:00:00  176th  17.094086
# 176       norway  2020-01-01 00:00:00  177th  16.191210
# 177      finland  2020-01-01 00:00:00  178th  14.626666
#
#      C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 173                     1.0                       1.8                  0.7
# 174                     1.6                       1.4                  4.0
# 175                     1.4                       1.0                  3.0
# 176                     1.8                       1.1                  3.6
# 177                     2.8                       1.4                  0.9
#
#      E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 173      2.80000                      1.0                               2.2
# ...

# %%
del df_cluster['Country']

# %%
del df_cluster['Year']

# %%
del df_cluster['Rank']

# %%
del df_cluster['Total']

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2633 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   C1: Security Apparatus            2633 non-null   float64
#  1   C2: Factionalized Elites          2633 non-null   float64
#  2   C3: Group Grievance               2633 non-null   float64
#  3   E1: Economy                       2633 non-null   float64
#  4   E2: Economic Inequality           2633 non-null   float64
#  5   E3: Human Flight and Brain Drain  2633 non-null   float64
#  6   P1: State Legitimacy              2633 non-null   float64
#  7   P2: Public Services               2633 non-null   float64
#  8   P3: Human Rights                  2633 non-null   float64
#  9   S1: Demographic Pressures         2633 non-null   float64
#  10  S2: Refugees and IDPs             2633 non-null   float64
# ...

# %%
df_cluster['Country_Year'] = df_cluster['Country_Year'].apply(lambda x: x.split('-')[0])

# %%
df_cluster.head()
# Out:
#    C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                     9.8                       9.1                  9.7
# 1                     9.8                       9.6                  9.1
# 2                     9.8                       9.8                  9.8
# 3                     9.8                       9.7                  9.8
# 4                     9.4                       8.5                  8.5
#
#    E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0          7.5                      9.2                               9.1
# 1          8.1                      9.0                               8.0
# 2          9.0                      8.0                               8.5
# 3          8.2                      8.7                               9.1
# 4          9.8                      9.2                               9.0
#
#    P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# ...

# %%
from sklearn.preprocessing import PowerTransformer

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2633 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   C1: Security Apparatus            2633 non-null   float64
#  1   C2: Factionalized Elites          2633 non-null   float64
#  2   C3: Group Grievance               2633 non-null   float64
#  3   E1: Economy                       2633 non-null   float64
#  4   E2: Economic Inequality           2633 non-null   float64
#  5   E3: Human Flight and Brain Drain  2633 non-null   float64
#  6   P1: State Legitimacy              2633 non-null   float64
#  7   P2: Public Services               2633 non-null   float64
#  8   P3: Human Rights                  2633 non-null   float64
#  9   S1: Demographic Pressures         2633 non-null   float64
#  10  S2: Refugees and IDPs             2633 non-null   float64
# ...

# %%
col = df_cluster.select_dtypes(include=['float64']).columns
col
# Out:
# Index(['C1: Security Apparatus', 'C2: Factionalized Elites',
#        'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
#        'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
#        'P2: Public Services', 'P3: Human Rights', 'S1: Demographic Pressures',
#        'S2: Refugees and IDPs', 'X1: External Intervention'],
#       dtype='object')

# %%
scaler = PowerTransformer(method = 'box-cox')
df_cluster[col] = scaler.fit_transform(df_cluster[col])

# %%
df_cluster.head()
# Out:
#    C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                1.805800                  1.232558             1.800606
# 1                1.805800                  1.483375             1.506146
# 2                1.805800                  1.585064             1.849714
# 3                1.805800                  1.534123             1.849714
# 4                1.623831                  0.938196             1.212015
#
#    E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0     0.931980                 1.646909                          1.866460
# 1     1.253989                 1.515454                          1.234896
# 2     1.741162                 0.883755                          1.518950
# 3     1.307879                 1.321432                          1.866460
# 4     2.178072                 1.646909                          1.808051
#
#    P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# ...

# %%
#Clustering

# %%
# Hopkins

#Calculating the Hopkins statistic
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan
 
def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n) 
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)
 
    rand_X = sample(range(0, n, 1), m)
 
    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])
 
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0
 
    return H

# %%
#Let's check the Hopkins measure
hopkins(df_cluster.drop(['Country_Year'],axis=1))
# Out:
# 0.8845462494801902

# %%
df_cluster_var = df_cluster.drop(['Country_Year'],axis=1)

# %%
# K-means clustering

# %%
#Let's check the silhouette score first to identify the ideal number of clusters
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
sse_ = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k).fit(df_cluster_var)
    sse_.append([k, silhouette_score(df_cluster_var, kmeans.labels_)])

# %%
plt.plot(pd.DataFrame(sse_)[0], pd.DataFrame(sse_)[1]);

# %%
#The sihouette score reaches a peak at around 2 clusters indicating that it might be the ideal number of clusters.
#Let's use the elbow curve method to identify the ideal number of clusters.
ssd = []
for num_clusters in list(range(1,10)):
    model_clus = KMeans(n_clusters = num_clusters, max_iter=50)
    model_clus.fit(df_cluster_var)
    ssd.append(model_clus.inertia_)

plt.plot(ssd)

# %%
#A distinct elbow is formed at around 2-4 clusters. Let's finally create the clusters and see for ourselves which ones fare better
#K-means with k=2 clusters
model_clus5 = KMeans(n_clusters = 2, max_iter=50)
model_clus5.fit(df_cluster_var)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=50,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
df_cluster.columns
# Out:
# Index(['C1: Security Apparatus', 'C2: Factionalized Elites',
#        'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
#        'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
#        'P2: Public Services', 'P3: Human Rights', 'S1: Demographic Pressures',
#        'S2: Refugees and IDPs', 'X1: External Intervention', 'Country_Year'],
#       dtype='object')

# %%
dat4 = df_cluster
dat4.index = pd.RangeIndex(len(dat4.index))
df_km = pd.concat([dat4, pd.Series(model_clus5.labels_)], axis=1)
df_km.columns = ['C1: Security Apparatus', 'C2: Factionalized Elites',
       'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
       'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
       'P2: Public Services', 'P3: Human Rights', 'S1: Demographic Pressures',
       'S2: Refugees and IDPs', 'X1: External Intervention', 'Country_Year','ClusterID']
df_km.head()
# Out:
#    C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                1.805800                  1.232558             1.800606
# 1                1.805800                  1.483375             1.506146
# 2                1.805800                  1.585064             1.849714
# 3                1.805800                  1.534123             1.849714
# 4                1.623831                  0.938196             1.212015
#
#    E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0     0.931980                 1.646909                          1.866460
# 1     1.253989                 1.515454                          1.234896
# 2     1.741162                 0.883755                          1.518950
# 3     1.307879                 1.321432                          1.866460
# 4     2.178072                 1.646909                          1.808051
#
#    P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# ...

# %%
df_km['ClusterID'].value_counts()
# Out:
# 0    1805
# 1     828
# Name: ClusterID, dtype: int64

# %%
l = df_km.columns[0:-2]
l
# Out:
# Index(['C1: Security Apparatus', 'C2: Factionalized Elites',
#        'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
#        'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
#        'P2: Public Services', 'P3: Human Rights', 'S1: Demographic Pressures',
#        'S2: Refugees and IDPs', 'X1: External Intervention'],
#       dtype='object')

# %%
from itertools import combinations 
  
def rSubset(lis, r): 
    return list(combinations(lis, r))

# %%
l2 = rSubset(l, 2)
l2
# Out:
# [('C1: Security Apparatus', 'C2: Factionalized Elites'),
#  ('C1: Security Apparatus', 'C3: Group Grievance'),
#  ('C1: Security Apparatus', 'E1: Economy'),
#  ('C1: Security Apparatus', 'E2: Economic Inequality'),
#  ('C1: Security Apparatus', 'E3: Human Flight and Brain Drain'),
#  ('C1: Security Apparatus', 'P1: State Legitimacy'),
#  ('C1: Security Apparatus', 'P2: Public Services'),
#  ('C1: Security Apparatus', 'P3: Human Rights'),
#  ('C1: Security Apparatus', 'S1: Demographic Pressures'),
#  ('C1: Security Apparatus', 'S2: Refugees and IDPs'),
#  ('C1: Security Apparatus', 'X1: External Intervention'),
#  ('C2: Factionalized Elites', 'C3: Group Grievance'),
#  ('C2: Factionalized Elites', 'E1: Economy'),
#  ('C2: Factionalized Elites', 'E2: Economic Inequality'),
#  ('C2: Factionalized Elites', 'E3: Human Flight and Brain Drain'),
#  ('C2: Factionalized Elites', 'P1: State Legitimacy'),
#  ('C2: Factionalized Elites', 'P2: Public Services'),
# ...

# %%
# for i in range(0, len(l2)):
#     for couple in l2:
#         plt.figure(i)
#         sns.scatterplot(x=couple[0],y=couple[1],hue='ClusterID',legend = False, data=df_km)

# %%
#Let's do some further visualizations.
#We'll be visualising the clusters on the basis of the original columns.
sns.scatterplot(x='C1: Security Apparatus',y='C2: Factionalized Elites',hue='ClusterID',legend='full',data=df_km)
# Out:
# <AxesSubplot:xlabel='C1: Security Apparatus', ylabel='C2: Factionalized Elites'>

# %%
sns.scatterplot(x='C1: Security Apparatus',y='C3: Group Grievance',hue='ClusterID',legend='full',data=df_km)
# Out:
# <AxesSubplot:xlabel='C1: Security Apparatus', ylabel='C3: Group Grievance'>

# %%
# 'C2: Factionalized Elites', 'C3: Group Grievance'
sns.scatterplot(x='C2: Factionalized Elites',y='C3: Group Grievance',hue='ClusterID',legend='full',data=df_km)
# Out:
# <AxesSubplot:xlabel='C2: Factionalized Elites', ylabel='C3: Group Grievance'>

# %%
# Testing of clusters
df_km.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2633 entries, 0 to 2632
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   C1: Security Apparatus            2633 non-null   float64
#  1   C2: Factionalized Elites          2633 non-null   float64
#  2   C3: Group Grievance               2633 non-null   float64
#  3   E1: Economy                       2633 non-null   float64
#  4   E2: Economic Inequality           2633 non-null   float64
#  5   E3: Human Flight and Brain Drain  2633 non-null   float64
#  6   P1: State Legitimacy              2633 non-null   float64
#  7   P2: Public Services               2633 non-null   float64
#  8   P3: Human Rights                  2633 non-null   float64
#  9   S1: Demographic Pressures         2633 non-null   float64
#  10  S2: Refugees and IDPs             2633 non-null   float64
# ...

# %%
#let's take a look at those countries clusters and try to make sense if the clustering process worked well.
df_km[df_km['ClusterID']==0]
# Out:
#       C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                   1.805800                  1.232558             1.800606
# 1                   1.805800                  1.483375             1.506146
# 2                   1.805800                  1.585064             1.849714
# 3                   1.805800                  1.534123             1.849714
# 4                   1.623831                  0.938196             1.212015
# ...                      ...                       ...                  ...
# 2562               -0.229935                  0.235992            -0.495715
# 2563               -0.357464                 -0.655585            -1.221944
# 2564                0.185439                  0.510865             1.604264
# 2565               -0.647239                  0.190994            -0.252748
# 2566               -0.693391                 -0.575821            -0.883584
#
# ...

# %%
df_km[df_km['ClusterID']==1]
# Out:
#       C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 101                -0.940885                 -0.962467            -0.301373
# 102                -0.101627                 -0.962467            -0.980364
# 103                -0.734922                 -1.035967             0.234283
# 104                -0.101627                  0.464481            -0.738268
# 105                -1.538203                 -1.178815            -0.495715
# ...                      ...                       ...                  ...
# 2628               -1.911508                 -1.713897            -2.559611
# 2629               -1.690672                 -1.818909            -0.980364
# 2630               -1.765462                 -1.913370            -1.462937
# 2631               -1.614885                 -1.890860            -1.173672
# 2632               -1.223941                 -1.818909            -2.465485
#
# ...

# %%
df_km[df_km['ClusterID']==1].count()
# Out:
# C1: Security Apparatus              828
# C2: Factionalized Elites            828
# C3: Group Grievance                 828
# E1: Economy                         828
# E2: Economic Inequality             828
# E3: Human Flight and Brain Drain    828
# P1: State Legitimacy                828
# P2: Public Services                 828
# P3: Human Rights                    828
# S1: Demographic Pressures           828
# S2: Refugees and IDPs               828
# X1: External Intervention           828
# Country_Year                        828
# ClusterID                           828
# dtype: int64

# %%
df_km[df_km['ClusterID']==0].count()
# Out:
# C1: Security Apparatus              1805
# C2: Factionalized Elites            1805
# C3: Group Grievance                 1805
# E1: Economy                         1805
# E2: Economic Inequality             1805
# E3: Human Flight and Brain Drain    1805
# P1: State Legitimacy                1805
# P2: Public Services                 1805
# P3: Human Rights                    1805
# S1: Demographic Pressures           1805
# S2: Refugees and IDPs               1805
# X1: External Intervention           1805
# Country_Year                        1805
# ClusterID                           1805
# dtype: int64

# %%
# So cluster 1 has the countries in respective years which are prone to conflict
df_km[df_km['ClusterID']==1].Country_Year
# Out:
# 101        romania _2006
# 102        bulgaria_2006
# 103        croatia _2006
# 104         kuwait _2006
# 105          ghana _2006
#               ...
# 2628        iceland_2020
# 2629        denmark_2020
# 2630    switzerland_2020
# 2631         norway_2020
# 2632        finland_2020
# Name: Country_Year, Length: 828, dtype: object

# %%
# To perform Hierarchical clustering
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
#Let's try hierarchical clustering to see if it works well
#First we'll try the single linkage procedure.
mergings = linkage(df_cluster_var, method = "single", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
#Let's try complete linkage method
mergings = linkage(df_cluster_var, method = "complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
#Okay now we are seeing some good clusters here. Let's see if they make sense if we eliminate the barriers
clusterCut = pd.Series(cut_tree(mergings, n_clusters = 2).reshape(-1,))
df_hc = pd.concat([df_cluster, clusterCut], axis=1)
df_hc.columns = ['C1: Security Apparatus', 'C2: Factionalized Elites',
       'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
       'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
       'P2: Public Services', 'P3: Human Rights', 'S1: Demographic Pressures',
       'S2: Refugees and IDPs', 'X1: External Intervention', 'Country_Year', 'ClusterID']

# %%
df_hc.tail()
# Out:
#       C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 2628               -1.911508                 -1.713897            -2.559611
# 2629               -1.690672                 -1.818909            -0.980364
# 2630               -1.765462                 -1.913370            -1.462937
# 2631               -1.614885                 -1.890860            -1.173672
# 2632               -1.223941                 -1.818909            -2.465485
#
#       E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 2628    -1.486703                -2.089230                         -1.583400
# 2629    -2.195662                -2.106957                         -1.802855
# 2630    -2.058144                -1.985466                         -1.871059
# 2631    -2.015829                -2.139030                         -1.998549
# 2632    -1.583889                -2.166162                         -1.767762
#
# ...

# %%
df_hc['ClusterID'].value_counts()
# Out:
# 0    1830
# 1     803
# Name: ClusterID, dtype: int64

# %%
df_hc[df_hc['ClusterID']==1]
# Out:
#       C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 101                -0.940885                 -0.962467            -0.301373
# 103                -0.734922                 -1.035967             0.234283
# 104                -0.101627                  0.464481            -0.738268
# 107                -0.442030                 -0.615849            -0.931984
# 108                -1.538203                 -0.962467            -0.738268
# ...                      ...                       ...                  ...
# 2628               -1.911508                 -1.713897            -2.559611
# 2629               -1.690672                 -1.818909            -0.980364
# 2630               -1.765462                 -1.913370            -1.462937
# 2631               -1.614885                 -1.890860            -1.173672
# 2632               -1.223941                 -1.818909            -2.465485
#
# ...

# %%
df_hc[df_hc['ClusterID']==0]
# Out:
#       C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                   1.805800                  1.232558             1.800606
# 1                   1.805800                  1.483375             1.506146
# 2                   1.805800                  1.585064             1.849714
# 3                   1.805800                  1.534123             1.849714
# 4                   1.623831                  0.938196             1.212015
# ...                      ...                       ...                  ...
# 2570                0.497386                 -1.108099            -1.703245
# 2573               -0.284196                 -0.117187            -0.786726
# 2575               -0.877109                 -1.248065            -0.980364
# 2577               -0.817654                  0.651355            -0.301373
# 2579               -0.276400                 -0.371420            -1.173672
#
# ...

# %%
# The above mentioned cluster is the cluster we need to focus on
#Let's visualise the clusters here. We don't see the countries properly clustered here. Hence we don't create cluster means
#as that would give a skewed result
df_vis = df_hc[df_hc['ClusterID'] == 0]
sns.scatterplot(x = 'E2: Economic Inequality',y = 'P3: Human Rights',data = df_vis)
# Out:
# <AxesSubplot:xlabel='E2: Economic Inequality', ylabel='P3: Human Rights'>

# %% [markdown]
# So now we have df_km the dataframe of K-Means and df_hc the dataframe of hierarchical clustering. Now we will compare it with the actual data from wikipedia (data has been extracted in a seperate jupyter notebook)

# %%
df_wiki = pd.read_excel('riotsListWiki2.xlsx')

# %%
df_wiki.columns
# Out:
# Index(['Year', 'Text', 'Countries', 'Actual'], dtype='object')

# %%
df_wiki['Countries'] = df_wiki['Countries'].str.lower()

# %%
df_wiki['Year'] = df_wiki['Year'].astype(str)

# %%
df_wiki['Country_Year'] = df_wiki[['Countries', 'Year']].apply(lambda x: '_'.join(x), axis = 1)

# %%
df_wiki.columns
# Out:
# Index(['Year', 'Text', 'Countries', 'Actual', 'Country_Year'], dtype='object')

# %%
df_wiki = df_wiki[['Country_Year', 'Actual']]

# %% [markdown]
# So now we have the confusion matrix data for wikipedia dataframe ready, now we will create the confusion matrix data for the other datasets i.e. df_km and df_hc

# %%
def parse_values(x):
    if x == 1:
       return 0
    else:
       return 1

df_km['Pred_km'] = df_km['ClusterID'].apply(parse_values)

# %%
def parse_values(x):
    if x == 0:
       return 1
    else:
       return 0

df_hc['Pred_hc'] = df_hc['ClusterID'].apply(parse_values)

# %%
df_km.columns
# Out:
# Index(['C1: Security Apparatus', 'C2: Factionalized Elites',
#        'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
#        'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
#        'P2: Public Services', 'P3: Human Rights', 'S1: Demographic Pressures',
#        'S2: Refugees and IDPs', 'X1: External Intervention', 'Country_Year',
#        'ClusterID', 'Pred_km'],
#       dtype='object')

# %%
df_km = df_km[['Country_Year','Pred_km']]

# %%
df_hc = df_hc[['Country_Year','Pred_hc']]

# %%
df_res = df_km.merge(df_hc, on='Country_Year', how='left')

# %%
df_res
# Out:
#                         Country_Year  Pred_km  Pred_hc
# 0                         sudan_2006        1        1
# 1     congo democratic republic_2006        1        1
# 2                 cote d'ivoire_2006        1        1
# 3                          iraq_2006        1        1
# 4                      zimbabwe_2006        1        1
# ...                              ...      ...      ...
# 2810                    iceland_2020        0        0
# 2811                    denmark_2020        0        0
# 2812                switzerland_2020        0        0
# 2813                     norway_2020        0        0
# 2814                    finland_2020        0        0
#
# [2815 rows x 3 columns]

# %%
df_cm = df_wiki.merge(df_res, on='Country_Year', how='left')

# %%
df_cm = df_cm.dropna(how='any',axis=0)

# %%
df_cm.reset_index()
# Out:
#      index      Country_Year  Actual  Pred_km  Pred_hc
# 0        1  afghanistan_2006       1      1.0      1.0
# 1        2      somalia_2006       1      1.0      1.0
# 2        3      lebanon_2006       1      1.0      1.0
# 3        4       turkey_2006       1      1.0      1.0
# 4        5     pakistan_2006       1      1.0      1.0
# ..     ...               ...     ...      ...      ...
# 363    388        libya_2020       1      1.0      1.0
# 364    389       sweden_2020       1      0.0      0.0
# 365    391      nigeria_2020       1      1.0      1.0
# 366    392  afghanistan_2020       1      1.0      1.0
# 367    393    indonesia_2020       1      1.0      1.0
#
# [368 rows x 5 columns]

# %%
df_cm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 1 to 393
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country_Year  368 non-null    object
#  1   Actual        368 non-null    int64
#  2   Pred_km       368 non-null    float64
#  3   Pred_hc       368 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 14.4+ KB

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# Scores on k-means set.
print(classification_report(df_cm['Actual'],df_cm['Pred_km']))
print(confusion_matrix(df_cm['Actual'],df_cm['Pred_km']))
print('Accuracy Score on k-means:  ',accuracy_score(df_cm['Actual'],df_cm['Pred_km']))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.70      0.82       368
#
#     accuracy                           0.70       368
#    macro avg       0.50      0.35      0.41       368
# weighted avg       1.00      0.70      0.82       368
#
# [[  0   0]
#  [111 257]]
# Accuracy Score on k-means:   0.6983695652173914
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Scores on hc set.
print(classification_report(df_cm['Actual'],df_cm['Pred_hc']))
print(confusion_matrix(df_cm['Actual'],df_cm['Pred_hc']))
print('Accuracy Score on the Hierarchical set:  ',accuracy_score(df_cm['Actual'],df_cm['Pred_hc']))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.70      0.83       368
#
#     accuracy                           0.70       368
#    macro avg       0.50      0.35      0.41       368
# weighted avg       1.00      0.70      0.83       368
#
# [[  0   0]
#  [109 259]]
# Accuracy Score on the Hierarchical set:   0.7038043478260869

# %%
from sklearn import metrics

# %% [markdown]
# ### Homogeneity, Completeness and V-Measure Scores

# %%
labels_true = df_cm['Actual']

# %%
labels_predKM = df_cm['Pred_km']

# %%
labels_predHC = df_cm['Pred_hc']

# %%
metrics.homogeneity_completeness_v_measure(labels_true, labels_predKM)
# Out:
# (1.0, 1.4507043439045496e-15, 2.901408687809095e-15)

# %%
metrics.homogeneity_completeness_v_measure(labels_true, labels_predHC)
# Out:
# (1.0, 0.0, 0.0)

# %% [markdown]
# ### Fowlkes-Mallows scores

# %%
metrics.fowlkes_mallows_score(labels_true, labels_predKM)
# Out:
# 0.7599690882171529

# %%
metrics.fowlkes_mallows_score(labels_true, labels_predHC)
# Out:
# 0.762847548298654

# %% [markdown]
# ### Contingency Matrix

# %%
from sklearn.metrics.cluster import contingency_matrix

# %%
contingency_matrix(labels_true, labels_predKM)
# Out:
# array([[111, 257]])

# %%
contingency_matrix(labels_true, labels_predHC)
# Out:
# array([[109, 259]])
